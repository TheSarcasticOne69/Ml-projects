# %% [markdown]
# <a href="https://colab.research.google.com/github/TheSarcasticOne69/Ml-projects/blob/main/practical_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **7.Implement and demonstrate support vector machine (SVM) algorithm for classification of a given set of training data samples read the training data from a .CSV file**

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split

data = pd.read_csv('data.csv')
X = data.iloc[:, :-1]
y = data.iloc[:, -1]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

model = SVC(kernel='linear')
model.fit(X_train, y_train)

plt.figure(figsize=(8, 6))

plt.scatter(X_train.iloc[:, 0], X_train.iloc[:, 1], c=y_train, cmap='coolwarm', edgecolors='k')

w = model.coef_[0]
b = model.intercept_[0]

x_vals = np.linspace(X.iloc[:, 0].min(), X.iloc[:, 0].max(), 100)
y_vals = -(w[0] * x_vals + b) / w[1]
plt.plot(x_vals, y_vals, 'k--', label='Hyperplane')

margin = 1 / (w @ w)**0.5
y_margin1 = -(w[0] * x_vals + b - 1) / w[1]
y_margin2 = -(w[0] * x_vals + b + 1) / w[1]
plt.plot(x_vals, y_margin1, 'r--', label='Margin')
plt.plot(x_vals, y_margin2, 'r--')

plt.scatter(model.support_vectors_[:, 0], model.support_vectors_[:, 1],
            s=100, facecolors='none', edgecolors='black', label='Support Vectors')

plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.title("SVM Hyperplane with Margins")
plt.legend()
plt.grid(True)
plt.show()

# %%
data.head(10)
# Out:
#    Feature1  Feature2  Label
# 0       2.5       2.4      0
# 1       0.5       0.7      0
# 2       2.2       2.9      0
# 3       1.9       2.2      0
# 4       3.1       3.0      0
# 5       2.3       2.7      0
# 6       2.0       1.6      0
# 7       1.0       1.1      0
# 8       1.5       1.6      0
# 9       1.1       0.9      0
